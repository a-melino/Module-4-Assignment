# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
from pandas_datareader import data

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
# Reading whale returns
whale_returns_path = Path("C:/Users/alex_/Desktop/Fintech Course/Module 4 Assignment/Starter_Code/Starter_Code/Module-4-Assignment/Resources/whale_returns.csv")
whale_returns_df = pd.read_csv(whale_returns_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
whale_returns_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
# Count nulls
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns_df = whale_returns_df.dropna()
whale_returns_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_returns_path = Path("C:/Users/alex_/Desktop/Fintech Course/Module 4 Assignment/Starter_Code/Starter_Code/Module-4-Assignment/Resources/algo_returns.csv")
algo_returns_df = pd.read_csv(algo_returns_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_returns_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
# Count nulls
algo_returns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns_df = algo_returns_df.dropna()
algo_returns_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx_history_path = Path("C:/Users/alex_/Desktop/Fintech Course/Module 4 Assignment/Starter_Code/Starter_Code/Module-4-Assignment/Resources/sp_tsx_history.csv")
sp_tsx_history_df = pd.read_csv(sp_tsx_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp_tsx_history_df
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99
# ...                ...
# 2019-12-20  $17,118.44
# 2019-12-23  $17,128.71
# 2019-12-24  $17,180.15
# 2019-12-27  $17,168.21
# 2019-12-30  $17,098.56
#
# [1818 rows x 1 columns]

# %%
# Check Data Types
sp_tsx_history_df['Close'].describe()
# Out:
# count           1818
# unique          1814
# top       $16,074.30
# freq               2
# Name: Close, dtype: object

# %%
# Fix Data Types
sp_tsx_history_df["Close"] = sp_tsx_history_df["Close"].str.strip("$")
sp_tsx_history_df["Close"] = sp_tsx_history_df["Close"].str.replace(',', '')
sp_tsx_history_df["Close"] = pd.to_numeric(sp_tsx_history_df["Close"])
sp_tsx_history_df.head()
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99

# %%
# Calculate Daily Returns
sp_tsx_returns = sp_tsx_history_df.pct_change()
sp_tsx_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305

# %%
# Drop nulls
sp_tsx_returns = sp_tsx_returns.dropna()
sp_tsx_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_tsx_returns = sp_tsx_returns.rename(columns = {"Close":"TSX 60"}) 
sp_tsx_returns.head()
# Out:
#               TSX 60
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
joined_data_df = pd.concat([whale_returns_df, algo_returns_df, sp_tsx_returns], axis="columns", join="outer")
joined_data_df = joined_data_df.dropna() 
joined_data_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
joined_data_df.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + joined_data_df).cumprod()
# Plot cumulative returns
cumulative_returns.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
cumulative_returns.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
standard_deviations = joined_data_df.std()
standard_deviations
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# TSX 60                         0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
    # Daily standard deviation of S&P TSX 60 calculated above: 0.007034
    
# Determine which portfolios are riskier than the S&P TSX 60
standard_deviations = standard_deviations.sort_values(ascending=True)
standard_deviations
# Out:
# PAULSON & CO.INC.              0.006982
# TSX 60                         0.007034
# Algo 1                         0.007589
# SOROS FUND MANAGEMENT LLC      0.007828
# Algo 2                         0.008326
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# dtype: float64

# %% [markdown]
# #### All the portfolios in this analysis are more risky than the S&P TSX 60 with the exception of the Paulson & Co. Inc. 'whale' portfolio.

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
std_dev_annual = standard_deviations * np.sqrt(252)
std_dev_annual = std_dev_annual.sort_values(ascending=True)
std_dev_annual
# Out:
# PAULSON & CO.INC.              0.110841
# TSX 60                         0.111664
# Algo 1                         0.120470
# SOROS FUND MANAGEMENT LLC      0.124259
# Algo 2                         0.132177
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
std_dev_21_day = joined_data_df.rolling(window=21).std()
# Plot the rolling standard deviation
std_dev_21_day.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = joined_data_df.corr()

# Display the correlation matrix
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.697076
# PAULSON & CO.INC.                             0.697076            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.560964            0.433034
# BERKSHIRE HATHAWAY INC                        0.750181            0.540033
# Algo 1                                        0.313795            0.266363
# Algo 2                                        0.826667            0.674015
# TSX 60                                        0.673930            0.486511
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.560964
# PAULSON & CO.INC.                               0.433034
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.423524
# Algo 1                                          0.161236
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
covariance = joined_data_df['BERKSHIRE HATHAWAY INC'].cov(joined_data_df['TSX 60'])
print(f"The covariance of the Berkshire Hathaway Inc portfolio with the S&P TSX 60 is {covariance}")

# Calculate variance of S&P TSX
TSX_variance = joined_data_df['TSX 60'].var()
print(f"The variance of the S&P TSX 60 is {TSX_variance}")

# Computing beta
BHI_beta = covariance / TSX_variance
print(f"The beta for the Berkshire Hathaway Inc portfolio in relation to the S&P TSX 60 is {BHI_beta}")

# Plot beta trend
rolling_variance = joined_data_df['TSX 60'].rolling(window=21).var()
rolling_covariance = joined_data_df['BERKSHIRE HATHAWAY INC'].rolling(window=21).cov(joined_data_df['TSX 60'])
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 21-Day Beta of BERKSHIRE HATHAWAY INC')
# Out:
# The covariance of the Berkshire Hathaway Inc portfolio with the S&P TSX 60 is 5.027336077110013e-05
# The variance of the S&P TSX 60 is 4.9479515915131015e-05
# The beta for the Berkshire Hathaway Inc portfolio in relation to the S&P TSX 60 is 1.0160439091063613
# <Axes: title={'center': 'Rolling 21-Day Beta of BERKSHIRE HATHAWAY INC'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = ((joined_data_df.mean()) * 252) / (joined_data_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# TSX 60                         0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Algorithm 1 outperforms all other portfolios as well as the S&P TSX 60 over this timeframe. Algorithm 2 also performed well but was
# outperformed by the Berkshire Hathaway Inc 'whale' portfolio. These results can be seen when looking at the overall returns of the portfolios and their Sharpe ratios.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
AAPL_path = Path("C:/Users/alex_/Desktop/Fintech Course/Module 4 Assignment/Starter_Code/Starter_Code/Module-4-Assignment/Resources/AAPL_historical.csv")
AAPL_df = pd.read_csv(AAPL_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
AAPL_df = AAPL_df.drop(["Open", "High", "Low", "Close", "Volume"], axis =1)
AAPL_df = AAPL_df.rename(columns = {"Adj Close":"Apple"}) 
AAPL_df.head()
# Out:
#                 Apple
# Date
# 2015-03-02  29.079880
# 2015-03-03  29.140709
# 2015-03-04  28.955986
# 2015-03-05  28.476170
# 2015-03-06  28.518959

# %%
# Reading data from 2nd stock
HD_path = Path("C:/Users/alex_/Desktop/Fintech Course/Module 4 Assignment/Starter_Code/Starter_Code/Module-4-Assignment/Resources/HD_historical.csv")
HD_df = pd.read_csv(HD_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
HD_df = HD_df.drop(["Open", "High", "Low", "Close", "Volume"], axis =1)
HD_df = HD_df.rename(columns = {"Adj Close":"Home Depot"}) 
HD_df.head()
# Out:
#             Home Depot
# Date
# 2015-03-02   95.431664
# 2015-03-03   95.390579
# 2015-03-04   94.313988
# 2015-03-05   95.259102
# 2015-03-06   94.059227

# %%
# Reading data from 3rd stock
KO_path = Path("C:/Users/alex_/Desktop/Fintech Course/Module 4 Assignment/Starter_Code/Starter_Code/Module-4-Assignment/Resources/KO_historical.csv")
KO_df = pd.read_csv(KO_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
KO_df = KO_df.drop(["Open", "High", "Low", "Close", "Volume"], axis =1)
KO_df = KO_df.rename(columns = {"Adj Close":"Coca Cola"}) 
KO_df.head()
# Out:
#             Coca Cola
# Date
# 2015-03-02  33.161053
# 2015-03-03  32.969154
# 2015-03-04  32.623726
# 2015-03-05  32.546951
# 2015-03-06  31.871452

# %%
# Combine all stocks in a single DataFrame
joined_portfolio_df = pd.concat([AAPL_df, HD_df, KO_df], axis="columns", join="outer")
joined_portfolio_df = joined_portfolio_df.dropna() 
joined_portfolio_df.head()
# Out:
#                 Apple  Home Depot  Coca Cola
# Date
# 2015-03-02  29.079880   95.431664  33.161053
# 2015-03-03  29.140709   95.390579  32.969154
# 2015-03-04  28.955986   94.313988  32.623726
# 2015-03-05  28.476170   95.259102  32.546951
# 2015-03-06  28.518959   94.059227  31.871452

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol

# %%
# Calculate daily returns
portfolio_returns_df = joined_portfolio_df.pct_change()

# Drop NAs
portfolio_returns_df = portfolio_returns_df.dropna()

# Display sample data
portfolio_returns_df.head()
# Out:
#                Apple  Home Depot  Coca Cola
# Date
# 2015-03-03  0.002092   -0.000431  -0.005787
# 2015-03-04 -0.006339   -0.011286  -0.010477
# 2015-03-05 -0.016571    0.010021  -0.002353
# 2015-03-06  0.001503   -0.012596  -0.020755
# 2015-03-09  0.004265    0.006990  -0.003131

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
weighted_returns_df = portfolio_returns_df.dot(weights)

# Display sample data
weighted_returns_df
# Out:
# Date
# 2015-03-03   -0.001375
# 2015-03-04   -0.009367
# 2015-03-05   -0.002968
# 2015-03-06   -0.010616
# 2015-03-09    0.002708
#                 ...
# 2019-04-25   -0.004352
# 2019-04-26   -0.003330
# 2019-04-29   -0.000763
# 2019-04-30    0.000527
# 2019-05-01    0.005150
# Length: 1049, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
all_data_df = pd.concat([joined_data_df, weighted_returns_df], axis="columns", join="outer")
all_data_df = all_data_df.rename(columns = {0:"Custom Portfolio"})

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_data_df = all_data_df.dropna()
all_data_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
all_data_std_dev = all_data_df.std() * np.sqrt(252)
all_data_std_dev = all_data_std_dev.sort_values(ascending=True)
all_data_std_dev
# Out:
# PAULSON & CO.INC.              0.110841
# TSX 60                         0.111664
# Algo 1                         0.120470
# SOROS FUND MANAGEMENT LLC      0.124259
# Algo 2                         0.132177
# Custom Portfolio               0.143892
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
all_data_std_dev_21_day = all_data_df.rolling(window=21).std() 

# Plot rolling standard deviation
all_data_std_dev_21_day.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
all_data_correlation = all_data_df.corr()
all_data_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.697076
# PAULSON & CO.INC.                             0.697076            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.560964            0.433034
# BERKSHIRE HATHAWAY INC                        0.750181            0.540033
# Algo 1                                        0.313795            0.266363
# Algo 2                                        0.826667            0.674015
# TSX 60                                        0.673930            0.486511
# Custom Portfolio                              0.642027            0.479500
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.560964
# PAULSON & CO.INC.                               0.433034
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.423524
# ...

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
custom_rolling_variance = all_data_df['TSX 60'].rolling(window=60).var()
custom_rolling_covariance = all_data_df['Custom Portfolio'].rolling(window=60).cov(all_data_df['TSX 60'])
custom_rolling_beta = custom_rolling_covariance / custom_rolling_variance
custom_rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of the Custom Portfolio')
# Out:
# <Axes: title={'center': 'Rolling 60-Day Beta of the Custom Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
custom_sharpe_ratios = ((all_data_df.mean()) * 252) / (all_data_df.std() * np.sqrt(252))
custom_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# TSX 60                         0.195550
# Custom Portfolio               0.791866
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
custom_sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %%
custom_cumulative_returns = (1 + all_data_df).cumprod()
custom_cumulative_returns.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### How does your portfolio do?
#
# The custom portfolio made up of Apple, Home Depot and Coca Cola stocks outperformed every other portfolio aside from the Algorithm 1 in terms of overall return and maximizing of the Sharpe Ratio.
